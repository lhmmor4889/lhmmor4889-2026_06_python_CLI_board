# %% [markdown]
# <a href="https://colab.research.google.com/github/lhmmor4889/lhmmor4889-2026_06_python_CLI_board/blob/main/%EB%B0%98%EB%B3%B5_%EA%B5%AC%EC%A1%B0_%EA%B8%80%EC%93%B0%EA%B8%B0_%EA%B5%AC%ED%98%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 반복연습용(복붙해서 사용하기)

# %%
print("== CLI 게시판 실행 ==")



while True:
    cmd = input("명령어 ) ")

    if cmd == "exit":
      break

    elif cmd == "article write":
      input("제목 : ")
      input("내용 : ")
      print("1번 글이 생성되었습니다")
    else:
      print("지원하지 않는 기능입니다")
    print("=========================")

번호, 제목, 내용

n = i+1




print(n, t, c)




print("== CLI 게시판 종료 ==")

# %% [markdown]
# 1. 게시글 생성시 번호 자동 증가 o
# 2. 명령어 article list 상황 구현 o
#
# 이전 코드에서 이어서 (2번째)
#
# 3. 게시글 삭제 기능 구현
# 4. 게시글 수정 기능 구현
# - ex) article edit 1
# 5. 게시글 상세보기 기능 구현
# - ex) article detail 1

# %%
print("== CLI 게시판 실행 ==")

last_article_id = 0
articles = [] # 게시글 저장소

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
      break

    elif cmd == "article write":
      last_article_id += 1
      id = last_article_id
      title = input("제목 : ")
      body = input("내용 : ")
      article = {"id" : id, "title" : title, "body" : body}
      # print(article)
      articles.append(article)
      print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
      if not articles:
        print("게시글이 없습니다")
      else:
        print("=========================================")
        print("   번호      /     제목       /     내용   ")
        for a in reversed(articles):
          print("   {}      /     {}       /     {}   ".format(a["id"], a["title"], a["body"]))
        print("=========================================")
    elif cmd.startswith("article delete"):
      cmdBits = cmd.split(" ")
      print(cmdBits[2])



    else:
      print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article list
# 등록된 게시글이 없습니다.
# 명령어 ) article write
# 제목 : 1
# 내용 : 2
# 1번 글이 생성 되었습니다.
# 명령어 ) article write
# 제목 : 3
# 내용 : 4
# 2번 글이 생성 되었습니다.
# 명령어 ) article write
# 제목 : 5
# 내용 : 6
# 3번 글이 생성 되었습니다.
# 명령어 ) article list
# ========================================
# 번호    /    제목    /    내용
# 3 /    5 /    6
# 2 /    3 /    4
# 1 /    1 /    2
# ========================================
# [{'id': 1, 'title': '1', 'content': '2'}, {'id': 2, 'title': '3', 'content': '4'}, {'id': 3, 'title': '5', 'content': '6'}]

# %% [markdown]
# 3. 게시글 삭제 기능 구현
# 4. 게시글 수정 기능 구현
# - ex) article edit 1
# 5. 게시글 상세보기 기능 구현
# - ex) article detail 1
#
# 연습용 2 (복사 하기)

# %%
print("== CLI 게시판 실행 ==")

last_article_id = 0
articles = [] # 게시글 저장소

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
      break

    elif cmd == "article write":
      last_article_id += 1
      id = last_article_id
      title = input("제목 : ")
      body = input("내용 : ")
      article = {"id" : id, "title" : title, "body" : body}
      # print(article)
      articles.append(article)
      print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
      if not articles:
        print("게시글이 없습니다")
      else:
        print("=========================================")
        print("   번호      /     제목       /     내용   ")
        for a in reversed(articles):
          print("   {}      /     {}       /     {}   ".format(a["id"], a["title"], a["body"]))
        print("=========================================")
    elif cmd.startswith("article delete"):
      cmdBits = cmd.split(" ")
      print(cmdBits[2])



    else:
      print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")

# %% [markdown]
# 다시 시작. < 중복제거 > 고통스러워..

# %%
from datetime import datetime

# ===== 공통 함수 (중복 제거) =====

def now():
    # 현재 시각을 "YYYY-MM-DD HH:MM:SS" 문자열로
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def parse_id(cmd):
    # "article delete 3" -> 3 을 뽑아준다. 잘못된 명령이면 None
    cmdBits = cmd.split(" ")
    if len(cmdBits) < 3:
        print("명령어를 확인해주세요(길이 모자람)")
        return None
    if not cmdBits[2].isdigit():
        print("명령어를 확인해주세요(번호대신 str 입력)")
        return None
    return int(cmdBits[2])

def find_article(articles, article_id): #추가된 딕셔너리값과
    # id가 맞는 글을 돌려준다. 없으면 None (found 플래그가 필요 없어짐)
    for article in articles:
        if article["id"] == article_id:
            return article #딕셔너리 값들
    return None

def format_date(regDate):
    # 오늘 쓴 글이면 시:분:초, 이전 글이면 연-월-일 로 보여준다
    today = now().split(" ")[0]        # "2026-06-30"
    datePart = regDate.split(" ")[0]   # 글의 날짜
    timePart = regDate.split(" ")[1]   # 글의 시각
    if datePart == today:
        return timePart
    else:
        return datePart


# ===== 메인 =====

print("== CLI 게시판 실행 ==")

last_article_id = 1
articles = [
    {"id": 1, "regDate": "2025-12-12 12:12:12", "updateDate": "2025-12-12 12:12:12", "title": "제목1", "body": "내용1"},
]

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
        break

    elif cmd == "article write":
        last_article_id += 1
        title = input("제목 : ")
        body = input("내용 : ")
        article = {
            "id": last_article_id,
            "regDate": now(),
            "updateDate": now(),
            "title": title,
            "body": body,
        }
        articles.append(article)
        print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
        if not articles:
            print("게시글이 없습니다")
        else:
            print("=========================================")
            print("   번호      /     제목       /     내용   /     작성일   ")
            for a in reversed(articles):
                print("   {}      /     {}       /     {}          /     {}   ".format(
                    a["id"], a["title"], a["body"], format_date(a["regDate"])))
            print("=========================================")

    elif cmd.startswith("article delete"):
        deletedId = parse_id(cmd)
        if deletedId is None:
            continue

        article = find_article(articles, deletedId)
        if article is None:
            print("{}번 글은 없습니다".format(deletedId))
            continue

        articles.remove(article)
        print("{}번 글이 삭제되었습니다".format(deletedId))

    elif cmd.startswith("article edit"):
        editedId = parse_id(cmd)
        if editedId is None:
            continue

        article = find_article(articles, editedId)
        if article is None:
            print("{}번 글은 없습니다".format(editedId))
            continue

        print("기존 제목 : {}".format(article["title"]))
        print("기존 내용 : {}".format(article["body"]))
        article["title"] = input("새 제목 : ")
        article["body"] = input("새 내용 : ")
        article["updateDate"] = now()
        print("{}번 글이 수정되었습니다".format(editedId))

    elif cmd.startswith("article detail"):
        detailId = parse_id(cmd)
        if detailId is None:
            continue

        article = find_article(articles, detailId)
        if article is None:
            print("{}번 글은 없습니다".format(detailId))
            continue

        print("번호 : {}".format(article["id"]))
        print("작성 날짜 : {}".format(article["regDate"]))
        print("수정 날짜 : {}".format(article["updateDate"]))
        print("제목 : {}".format(article["title"]))
        print("내용 : {}".format(article["body"]))

    else:
        print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 )
# 지원하지 않는 기능입니다
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2315/2197033833.py in <cell line: 0>()
#      46
#      47 while True:
# ---> 48     cmd = input("명령어 ) ").strip()
#      49
#      50     if cmd == "exit":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# 아랫게 제일 최신

# %%
from datetime import datetime
from dataclasses import dataclass

@dataclass
class Article:
  id: int
  regDate: str
  updateDate: str
  title: str
  body: str

@dataclass
class Member:
  id: int
  regDate: str
  updateDate: str
  loginId: str
  loginPw: str
  name: str

# ===== 공통 함수 (중복 제거) =====

def now():
    # 현재 시각을 "YYYY-MM-DD HH:MM:SS" 문자열로
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def parse_id(cmd):
    # "article delete 3" -> 3 을 뽑아준다. 잘못된 명령이면 None
    cmdBits = cmd.split(" ")
    if len(cmdBits) < 3:
        print("명령어를 확인해주세요(길이 모자람)")
        return None
    if not cmdBits[2].isdigit():
        print("명령어를 확인해주세요(번호대신 str 입력)")
        return None
    return int(cmdBits[2])

def find_article(articles, article_id):
    # id가 맞는 글을 돌려준다. 없으면 None (found 플래그가 필요 없어짐)
    for article in articles:
        if article.id == article_id:
            return article
    return None

def format_date(regDate):
    # 오늘 쓴 글이면 시:분:초, 이전 글이면 연-월-일 로 보여준다
    today = now().split(" ")[0]        # "2026-06-30"
    datePart = regDate.split(" ")[0]   # 글의 날짜
    timePart = regDate.split(" ")[1]   # 글의 시각
    if datePart == today:
        return timePart
    else:
        return datePart

def make_article_TestData():
  # 시작하자마자 넣어둘 테스트용 글 3개를 만들어서 리스트로 리턴한다
  # 1번은 이전 날짜 -> 목록 날짜 표기 테스트용
  return [
      Article(1, "2025-12-12 12:12:12","2025-12-12 12:12:12", "제목1", "내용1"),
      Article(2, now(), now(), "제목2", "내용2"),
      Article(3, now(), now(), "제목3", "내용3"),
          ]


def make_member_TestData():
  return [
      Member(1, now(),now(), "test1", "test1", "회원1"),
      Member(2, now(), now(), "test2", "test2", "회원2"),
          ]

# ===== 메인 =====

print("== CLI 게시판 실행 ==")

last_article_id = 3
last_member_id = 2
articles = make_article_TestData()
members = make_member_TestData()

loginedMember = None

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
        break

    elif cmd == "member join":
        if loginedMember is not None:
          print("이미 로그인중인데?")
          continue

        last_member_id += 1
        while True:
          loginId = input("loginId : ")

          isDup = False

          for member in members:
            if member.loginId == loginId:
              isDup = True
              break

          if isDup:
            print("이미 사용중인 loginId야")
            continue
          break

        while True:
          loginPw = input("loginPw : ")
          loginPwConfirm = input("loginPwConfirm : ")
          if loginPw != loginPwConfirm:
            print("비번 불일치")
            continue
          break
        name = input("name : ")
        member = Member(last_member_id, now(), now(), loginId, loginPw, name)
        members.append(member)
        print("{}번 회원이 가입되었습니다".format(last_member_id))
        print(members)

    elif cmd == "member login":

      if loginedMember is not None:
        print("이미 로그인중인데?")
        continue

      loginId = input("loginId : ")
      loginPw = input("loginPw : ")

      member = None

      for m in members:
        if m.loginId == loginId:
          member = m
          break

      if member is None:
        print("일치하는 아이디가 없다")
        continue

      if member.loginPw != loginPw:
        print("비번 틀림")
        continue
## 여기서 하면 될 것 같은데? 그러면 바로 로그인 성공한 거잖아. 그러면 바로 알티클라이트를 할 수 있는 권한을???
      loginedMember = member
      # print(loginedMember)
      print("{}님, 로그인 성공!".format(member.name))

    elif cmd == "member logout":
      if loginedMember is None:
        print("로그인 하고 이용해")
        continue

      loginedMember = None

      print("로그아웃!")


    elif cmd == "article write":
        last_article_id += 1
        title = input("제목 : ")
        body = input("내용 : ")
        article = Article(last_article_id, now(), now(), title, body)
        articles.append(article)
        print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
        if not articles:
            print("게시글이 없습니다")
        else:
            print("=========================================")
            print("   번호      /     제목       /     내용   /     작성일   ")
            for a in reversed(articles):
                print("   {}      /     {}       /     {}          /     {}   ".format(
                    a.id, a.title, a.body, format_date(a.regDate)))
            print("=========================================")

    elif cmd.startswith("article delete"):
        deletedId = parse_id(cmd)
        if deletedId is None:
            continue

        article = find_article(articles, deletedId)
        if article is None:
            print("{}번 글은 없습니다".format(deletedId))
            continue

        articles.remove(article)
        print("{}번 글이 삭제되었습니다".format(deletedId))

    elif cmd.startswith("article edit"):
        editedId = parse_id(cmd)
        if editedId is None:
            continue

        article = find_article(articles, editedId)
        # 1. 함수가 자기 재료를 눈에 보이게 받는게 더 안전하고 명확함
        # 2. 클래스 사용시 편함(전역에 의존하면 안됨)
        # -> '이 함수가 뭘 필요로 하는지 인자로 다 받는다' 의 습관
        # -> "함수는 독립적이어야 한다"
        if article is None:
            print("{}번 글은 없습니다".format(editedId))
            continue

        print("기존 제목 : {}".format(article.title))
        print("기존 내용 : {}".format(article.body))
        article.title = input("새 제목 : ")
        article.body = input("새 내용 : ")
        article.updateDate = now()
        print("{}번 글이 수정되었습니다".format(editedId))

    elif cmd.startswith("article detail"):
        detailId = parse_id(cmd)
        if detailId is None:
            continue

        article = find_article(articles, detailId)
        if article is None:
            print("{}번 글은 없습니다".format(detailId))
            continue

        print("번호 : {}".format(article.id))
        print("작성 날짜 : {}".format(article.regDate))
        print("수정 날짜 : {}".format(article.updateDate))
        print("제목 : {}".format(article.title))
        print("내용 : {}".format(article.body))

    else:
        print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")

# %%
elif cmd == "article write":
    # 1) 로그인 한 회원 id 번호 값이 없으면 끝!
    if logined_member_id is None:  # 또는 logined_member_id == 0
        print("로그인 후 이용 가능합니다.")
        continue

    # 2) 있으면 정상 진행
    title = input("title : ")
    body = input("body : ")

    last_article_id += 1

    # ⭐ [핵심] 글을 만들 때 현재 로그인한 회원의 ID(logined_member_id)를 같이 저장합니다!
    new_article = Article(last_article_id, now(), now(), title, body, logined_member_id)
    articles.append(new_article)

    print("{}번 글이 등록되었습니다.".format(last_article_id))






    elif cmd.startswith("article modify"):
    # 1) 로그인 한 회원 id 번호 값이 없으면 끝.
    if logined_member_id is None:
        print("로그인 후 이용 가능합니다.")
        continue

    # parse_id 함수로 몇 번 글을 수정할지 가져옴 (예: article modify 3 -> 3)
    target_id = parse_id(cmd)
    if target_id is None:
        continue

    # 전체 글에서 해당 글 찾기
    found_article = None
    for article in articles:
        if article.id == target_id:
            found_article = article
            break

    if found_article is None:
        print("{}번 게시물은 존재하지 않습니다.".format(target_id))
        continue

    # 2) 쓰여진 글의 주인 id 값과 로그인한 id 값이 일치하는가?
    # [글 내부의 작성자 번호] 와 [현재 로그인한 내 번호]를 비교!
    if found_article.member_id != logined_member_id:
        print("본인이 작성한 글만 수정할 수 있습니다.")
        continue

    # 3) 일치하면 수정 진행
    new_title = input("new title : ")
    new_body = input("new body : ")

    found_article.title = new_title
    found_article.body = new_body
    found_article.updateDate = now() # 수정 시간 갱신

    print("{}번 게시물이 수정되었습니다.".format(target_id))

# %%
from datetime import datetime
from dataclasses import dataclass

@dataclass
class Article:
  id: int
  regDate: str
  updateDate: str
  title: str
  body: str

@dataclass
class Member:
  id: int
  regDate: str
  updateDate: str
  loginId: str
  loginPw: str
  name: str

# ===== 공통 함수 (중복 제거) =====

def now():
    # 현재 시각을 "YYYY-MM-DD HH:MM:SS" 문자열로
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def parse_id(cmd):
    # "article delete 3" -> 3 을 뽑아준다. 잘못된 명령이면 None
    cmdBits = cmd.split(" ")
    if len(cmdBits) < 3:
        print("명령어를 확인해주세요(길이 모자람)")
        return None
    if not cmdBits[2].isdigit():
        print("명령어를 확인해주세요(번호대신 str 입력)")
        return None
    return int(cmdBits[2])

def find_article(articles, article_id):
    # id가 맞는 글을 돌려준다. 없으면 None (found 플래그가 필요 없어짐)
    for article in articles:
        if article.id == article_id:
            return article
    return None

def format_date(regDate):
    # 오늘 쓴 글이면 시:분:초, 이전 글이면 연-월-일 로 보여준다
    today = now().split(" ")[0]        # "2026-06-30"
    datePart = regDate.split(" ")[0]   # 글의 날짜
    timePart = regDate.split(" ")[1]   # 글의 시각
    if datePart == today:
        return timePart
    else:
        return datePart

def make_article_TestData():
  # 시작하자마자 넣어둘 테스트용 글 3개를 만들어서 리스트로 리턴한다
  # 1번은 이전 날짜 -> 목록 날짜 표기 테스트용
  return [
      Article(1, "2025-12-12 12:12:12","2025-12-12 12:12:12", "제목1", "내용1"),
      Article(2, now(), now(), "제목2", "내용2"),
      Article(3, now(), now(), "제목3", "내용3"),
          ]


def make_member_TestData():
  return [
      Member(1, now(),now(), "test1", "test1", "회원1"),
      Member(2, now(), now(), "test2", "test2", "회원2"),
          ]

# ===== 메인 =====

print("== CLI 게시판 실행 ==")

last_article_id = 3
last_member_id = 2
articles = make_article_TestData()
members = make_member_TestData()

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
        break

    elif cmd == "member join": # 회원가입
        last_member_id += 1
        while True:
          loginId = input("loginId : ")

          isDup = False

          for member in members: # 로그인??? 이 되어있는거 아닌가? 잠깐만~~ 직접 로그인 을 해야지..!
            if member.loginId == loginId:

              isDup = True
              break

          if isDup: # 이미 사용중
            print("이미 사용중인 loginId야")
            continue
          break

        while True:
          loginPw = input("loginPw : ") # 반복해서 확인 비밀번호 이중 확인
          loginPwConfirm = input("loginPwConfirm : ")
          if loginPw != loginPwConfirm:
            print("비번 불일치")
            continue
          break
        name = input("name : ")
        member = Member(last_member_id, now(), now(), loginId, loginPw, name)
        members.append(member)
        print("{}번 회원이 가입되었습니다".format(last_member_id))
        print(members)

      elif cmd == "member login": # 로그인을 치면 확인을 해야겠지?
          if member.loginId == loginId: # 확인을 해! 만약 있으면?로그인이 되었습니다. 하고 만약 없으면 아이디를 확인해 보세요.
            print("로그인이 되었습니다.")

          else: print("아이디를 확인해 보세요.")

    elif cmd == "article write":
        last_article_id += 1
        title = input("제목 : ")
        body = input("내용 : ")
        article = Article(last_article_id, now(), now(), title, body)
        articles.append(article)
        print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
        if not articles:
            print("게시글이 없습니다")
        else:
            print("=========================================")
            print("   번호      /     제목       /     내용   /     작성일   ")
            for a in reversed(articles):
                print("   {}      /     {}       /     {}          /     {}   ".format(
                    a.id, a.title, a.body, format_date(a.regDate)))
            print("=========================================")

    elif cmd.startswith("article delete"):
        deletedId = parse_id(cmd)
        if deletedId is None:
            continue

        article = find_article(articles, deletedId)
        if article is None:
            print("{}번 글은 없습니다".format(deletedId))
            continue

        articles.remove(article)
        print("{}번 글이 삭제되었습니다".format(deletedId))

    elif cmd.startswith("article edit"):
        editedId = parse_id(cmd)
        if editedId is None:
            continue

        article = find_article(articles, editedId)
        # 1. 함수가 자기 재료를 눈에 보이게 받는게 더 안전하고 명확함
        # 2. 클래스 사용시 편함(전역에 의존하면 안됨)
        # -> '이 함수가 뭘 필요로 하는지 인자로 다 받는다' 의 습관
        # -> "함수는 독립적이어야 한다"
        if article is None:
            print("{}번 글은 없습니다".format(editedId))
            continue

        print("기존 제목 : {}".format(article.title))
        print("기존 내용 : {}".format(article.body))
        article.title = input("새 제목 : ")
        article.body = input("새 내용 : ")
        article.updateDate = now()
        print("{}번 글이 수정되었습니다".format(editedId))

    elif cmd.startswith("article detail"):
        detailId = parse_id(cmd)
        if detailId is None:
            continue

        article = find_article(articles, detailId)
        if article is None:
            print("{}번 글은 없습니다".format(detailId))
            continue

        print("번호 : {}".format(article.id))
        print("작성 날짜 : {}".format(article.regDate))
        print("수정 날짜 : {}".format(article.updateDate))
        print("제목 : {}".format(article.title))
        print("내용 : {}".format(article.body))

    else:
        print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
# Out:
#   File "<tokenize>", line 117
#     elif cmd == "member login": # 로그인을 치면 확인을 해야겠지?
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
from datetime import datetime
from dataclasses import dataclass

@dataclass
class Article:
  id: int
  regDate: str
  updateDate: str
  title: str
  body: str

@dataclass
class Member:
  id: int
  regDate: str
  updateDate: str
  loginId: str
  loginPw: str
  name: str

# ===== 공통 함수 (중복 제거) =====

def now():
    # 현재 시각을 "YYYY-MM-DD HH:MM:SS" 문자열로
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def parse_id(cmd):
    # "article delete 3" -> 3 을 뽑아준다. 잘못된 명령이면 None
    cmdBits = cmd.split(" ")
    if len(cmdBits) < 3:
        print("명령어를 확인해주세요(길이 모자람)")
        return None
    if not cmdBits[2].isdigit():
        print("명령어를 확인해주세요(번호대신 str 입력)")
        return None
    return int(cmdBits[2])

def find_article(articles, article_id):
    # id가 맞는 글을 돌려준다. 없으면 None (found 플래그가 필요 없어짐)
    for article in articles:
        if article.id == article_id:
            return article
    return None

def format_date(regDate):
    # 오늘 쓴 글이면 시:분:초, 이전 글이면 연-월-일 로 보여준다
    today = now().split(" ")[0]        # "2026-06-30"
    datePart = regDate.split(" ")[0]   # 글의 날짜
    timePart = regDate.split(" ")[1]   # 글의 시각
    if datePart == today:
        return timePart
    else:
        return datePart

def make_article_TestData():
  # 시작하자마자 넣어둘 테스트용 글 3개를 만들어서 리스트로 리턴한다
  # 1번은 이전 날짜 -> 목록 날짜 표기 테스트용
  return [
      Article(1, "2025-12-12 12:12:12","2025-12-12 12:12:12", "제목1", "내용1"),
      Article(2, now(), now(), "제목2", "내용2"),
      Article(3, now(), now(), "제목3", "내용3"),
          ]


def make_member_TestData():
  return [
      Member(1, now(),now(), "test1", "test1", "회원1"),
      Member(2, now(), now(), "test2", "test2", "회원2"),
          ]

# ===== 메인 =====

print("== CLI 게시판 실행 ==")

last_article_id = 3
last_member_id = 2
articles = make_article_TestData()
members = make_member_TestData()

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
        break
    elif cmd ==
    id_exists = False
    for member in members:
        if member.loginId == loginId:
            id_exists = True
            break
### 로그인 아이디 리스트 값 members인건 맞는데.... 멤버스 값이 들어갔는지 아닌지를 확인을 해야하는데. 멤버스 값을 넣어야지. 이 형태가 어디있었어. 참고하셈 제발 ㅠㅜ 아티클에서//
# 특히 멤버스 리스트 값에 ~있는 중이면 순회해야지.



    elif cmd == "member join":
        last_member_id += 1
        loginId = input("loginId : ")
        loginPw = input("loginPw : ")
        loginPwConfirm = input("loginPwConfirm : ")
        if loginPw != loginPwConfirm:
          print("비밀번호가 일치하지 않습니다. 다시 시도해주세요.")
          continue  # 가입을 중단하고 다음 명령 입력으로 넘어감
        #같다면 통과. 아니라면 중복되었습니다. 하고
        name = input("name : ")
        member = Member(last_member_id, now(), now(), loginId, loginPw, name)
        members.append(member)
        print("{}번 회원이 가입되었습니다".format(last_member_id))
        print(members)
## 지금 이거 해야하는건데, 뭘 해야하냐 중복체크해서 비밀번호 끼리 맞는지 아닌지 구분하게 하는거임.





    elif cmd == "article write":
        last_article_id += 1
        title = input("제목 : ")
        body = input("내용 : ")
        article = Article(last_article_id, now(), now(), title, body)
        articles.append(article)
        print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
        if not articles:
            print("게시글이 없습니다")
        else:
            print("=========================================")
            print("   번호      /     제목       /     내용   /     작성일   ")
            for a in reversed(articles):
                print("   {}      /     {}       /     {}          /     {}   ".format(
                    a.id, a.title, a.body, format_date(a.regDate)))
            print("=========================================")

    elif cmd.startswith("article delete"):
        deletedId = parse_id(cmd)
        if deletedId is None:
            continue

        article = find_article(articles, deletedId)
        if article is None:
            print("{}번 글은 없습니다".format(deletedId))
            continue

        articles.remove(article)
        print("{}번 글이 삭제되었습니다".format(deletedId))

    elif cmd.startswith("article edit"):
        editedId = parse_id(cmd)
        if editedId is None:
            continue

        article = find_article(articles, editedId)
        # 1. 함수가 자기 재료를 눈에 보이게 받는게 더 안전하고 명확함
        # 2. 클래스 사용시 편함(전역에 의존하면 안됨)
        # -> '이 함수가 뭘 필요로 하는지 인자로 다 받는다' 의 습관
        # -> "함수는 독립적이어야 한다"
        if article is None:
            print("{}번 글은 없습니다".format(editedId))
            continue

        print("기존 제목 : {}".format(article.title))
        print("기존 내용 : {}".format(article.body))
        article.title = input("새 제목 : ")
        article.body = input("새 내용 : ")
        article.updateDate = now()
        print("{}번 글이 수정되었습니다".format(editedId))

    elif cmd.startswith("article detail"):
        detailId = parse_id(cmd)
        if detailId is None:
            continue

        article = find_article(articles, detailId)
        if article is None:
            print("{}번 글은 없습니다".format(detailId))
            continue

        print("번호 : {}".format(article.id))
        print("작성 날짜 : {}".format(article.regDate))
        print("수정 날짜 : {}".format(article.updateDate))
        print("제목 : {}".format(article.title))
        print("내용 : {}".format(article.body))

    else:
        print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) member join
# loginId : 안녕
# loginPw : 개똥
# loginPwConfirm : 벌레
# 비밀번호가 일치하지 않습니다. 다시 시도해주세요.
# 명령어 ) member join
# loginId :
# loginPw : 후후후
# loginPwConfirm : 하하핫
# 비밀번호가 일치하지 않습니다. 다시 시도해주세요.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2315/2163756800.py in <cell line: 0>()
#      79
#      80 while True:
# ---> 81     cmd = input("명령어 ) ").strip()
#      82
#      83     if cmd == "exit":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
elif cmd == "member join":
    loginId = input("loginId : ").strip()

    # 1. 아이디 중복 체크
    id_exists = False
    for member in members:
        if member.loginId == loginId:
            id_exists = True
            break

    if id_exists:
        print("이미 존재하는 아이디입니다. 다시 시도해주세요.")
        continue  # 다음 명령 입력으로 넘어감

    loginPw = input("loginPw : ")
    loginPwConfirm = input("loginPwConfirm : ")

    # 2. 비밀번호 일치 확인
    if loginPw != loginPwConfirm:
        print("비밀번호가 일치하지 않습니다. 다시 시도해주세요.")
        continue  # 가입을 중단하고 다음 명령 입력으로 넘어감

    # 3. 중복과 비밀번호 통과 시 회원가입 완료
    name = input("name : ")

    last_member_id += 1
    new_member = Member(last_member_id, now(), now(), loginId, loginPw, name)
    members.append(new_member)

    print("{}번 회원이 가입되었습니다.".format(last_member_id))
    print(members)

# %%
## 내가한 풀이..


class Member_join::
  def __init__(self, id, regDate, loginId, loginPw, name):
    self.id = id
    self.regDate = regDate
    self.loginId = loginId
    self.loginPw = loginPw
    self.name = name

members_id = 0
members = []


while True:
    print("회원가입 ) ").strip()
    loginId = input("아이디 : ")
    loginPw = input("비번 : ")



#일단 회원가입을 하고 나서 그 리스트를 불러와서 일치하는지를 봐야할 것 같은데? 일단 회원가입을 완료시키자. 처음은 없어.
    if cmd == "exit":
        break


    elif cmd == "     ": # 가만 이걸.. 그냥?? 자동으로 실행이 되나?
        members_id += 1
        loginId = input("아이디 : ")
        loginPw = input("비번 : ")
        # article = {   -> 코드 곳곳에 흩어져있다
        #     "id": last_article_id,
        #     "regDate": now(),
        #     "updateDate": now(),
        #     "title": title,
        #     "body": body,
        # }
        article = Article(last_article_id, now(), now(), title, body)
        articles.append(article)
        print("{}번 글이 생성되었습니다".format(last_article_id))

# %%
from datetime import datetime

class Article:
  def __init__(self, id, regDate, updateDate, title, body):
    # 생성자 -> 글 하나가 만들어질 때 자동으로 불리는 함수
    # self => 지금 만들어지는 바로 그 글 자신
    self.id = id
    self.regDate = regDate
    self.updateDate = updateDate
    self.title = title
    self.body = body


class Member_join:
  def __init__(self, id, regDate, loginId, loginPw, name):
    self.id = id
    self.regDate = regDate
    self.loginId = loginId
    self.loginPw = loginPw
    self.name = name



# ===== 공통 함수 (중복 제거) =====

def now():
    # 현재 시각을 "YYYY-MM-DD HH:MM:SS" 문자열로
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def parse_id(cmd):
    # "article delete 3" -> 3 을 뽑아준다. 잘못된 명령이면 None
    cmdBits = cmd.split(" ")
    if len(cmdBits) < 3:
        print("명령어를 확인해주세요(길이 모자람)")
        return None
    if not cmdBits[2].isdigit():
        print("명령어를 확인해주세요(번호대신 str 입력)")
        return None
    return int(cmdBits[2])

def find_article(articles, article_id):
    # id가 맞는 글을 돌려준다. 없으면 None (found 플래그가 필요 없어짐)
    for article in articles:
        if article.id == article_id:
            return article
    return None

def format_date(regDate):
    # 오늘 쓴 글이면 시:분:초, 이전 글이면 연-월-일 로 보여준다
    today = now().split(" ")[0]        # "2026-06-30"
    datePart = regDate.split(" ")[0]   # 글의 날짜
    timePart = regDate.split(" ")[1]   # 글의 시각
    if datePart == today:
        return timePart
    else:
        return datePart

def makeTestData():
  # 시작하자마자 넣어둘 테스트용 글 3개를 만들어서 리스트로 리턴한다
  # 1번은 이전 날짜 -> 목록 날짜 표기 테스트용
  return [
      Article(1, "2025-12-12 12:12:12","2025-12-12 12:12:12", "제목1", "내용1"),
      Article(2, now(), now(), "제목2", "내용2"),
      Article(3, now(), now(), "제목3", "내용3"),

      # {"id" : 1, "regDate" : "2025-12-12 12:12:12", "loginId" : "2025-12-12 12:12:12", "title" : "제목1","body":"내용1"},
      # {"id" : 2, "regDate" : now(), "updateDate" : now(), "title" : "제목2","body":"내용2"},
      # {"id" : 3, "regDate" : now(), "updateDate" : now(), "title" : "제목3","body":"내용3"}
          ]

# ===== 메인 =====

print("== CLI 게시판 실행 ==")

last_article_id = 3
articles = makeTestData()

while True:

# 여기다가 치고 아무튼 회원가입 부터 시켜야함. 일단 회원가입을 시키려면 아이디 중복검사를 시켜야하잖아? 딕셔너리 때 어떻게 했지? 리스트 값이 담겨진 article 의 아이디값을 불러와서 체크했었음
# 근데 회원가입 시에 순서번호로 가능했을까? 따로 리스트를 만들어? 변수가 달라. 변숫값이 음음.결국 리스트를 만들어야한다? 그렇다면 리스트 이름을 대충 Member_join이라
# 부르고 여기에 members = Members_join(인자값) 해놓고 멤버스에 추가 멤버

    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
        break

    elif cmd == "article write":
        last_article_id += 1
        title = input("제목 : ")
        body = input("내용 : ")
        # article = {   -> 코드 곳곳에 흩어져있다
        #     "id": last_article_id,
        #     "regDate": now(),
        #     "updateDate": now(),
        #     "title": title,
        #     "body": body,
        # }
        article = Article(last_article_id, now(), now(), title, body)
        articles.append(article)
        print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
        if not articles:
            print("게시글이 없습니다")
        else:
            print("=========================================")
            print("   번호      /     제목       /     내용   /     작성일   ")
            for a in reversed(articles):
                print("   {}      /     {}       /     {}          /     {}   ".format(
                    a.id, a.title, a.body, format_date(a.regDate)))
            print("=========================================")

    elif cmd.startswith("article delete"):
        deletedId = parse_id(cmd)
        if deletedId is None:
            continue

        article = find_article(articles, deletedId)
        if article is None:
            print("{}번 글은 없습니다".format(deletedId))
            continue

        articles.remove(article)
        print("{}번 글이 삭제되었습니다".format(deletedId))

    elif cmd.startswith("article edit"):
        editedId = parse_id(cmd)
        if editedId is None:
            continue

        article = find_article(articles, editedId)
        # 1. 함수가 자기 재료를 눈에 보이게 받는게 더 안전하고 명확함
        # 2. 클래스 사용시 편함(전역에 의존하면 안됨)
        # -> '이 함수가 뭘 필요로 하는지 인자로 다 받는다' 의 습관
        # -> "함수는 독립적이어야 한다"
        if article is None:
            print("{}번 글은 없습니다".format(editedId))
            continue

        print("기존 제목 : {}".format(article.title))
        print("기존 내용 : {}".format(article.body))
        article.title = input("새 제목 : ")
        article.body = input("새 내용 : ")
        article.updateDate = now()
        print("{}번 글이 수정되었습니다".format(editedId))

    elif cmd.startswith("article detail"):
        detailId = parse_id(cmd)
        if detailId is None:
            continue

        article = find_article(articles, detailId)
        if article is None:
            print("{}번 글은 없습니다".format(detailId))
            continue

        print("번호 : {}".format(article.id))
        print("작성 날짜 : {}".format(article.regDate))
        print("수정 날짜 : {}".format(article.updateDate))
        print("제목 : {}".format(article.title))
        print("내용 : {}".format(article.body))

    else:
        print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")

# %%
from datetime import datetime

# ===== 공통 함수 (중복 제거) =====

def now():
    # 현재 시각을 "YYYY-MM-DD HH:MM:SS" 문자열로
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def parse_id(cmd):
    # "article delete 3" -> 3 을 뽑아준다. 잘못된 명령이면 None
    cmdBits = cmd.split(" ")
    if len(cmdBits) < 3:
        print("명령어를 확인해주세요(길이 모자람)")
        return None
    if not cmdBits[2].isdigit():
        print("명령어를 확인해주세요(번호대신 str 입력)")
        return None
    return int(cmdBits[2])

def find_article(articles, article_id):
    # id가 맞는 글을 돌려준다. 없으면 None (found 플래그가 필요 없어짐)
    for article in articles:
        if article["id"] == article_id:
            return article
    return None

def format_date(regDate):
    # 오늘 쓴 글이면 시:분:초, 이전 글이면 연-월-일 로 보여준다
    today = now().split(" ")[0]        # "2026-06-30"
    datePart = regDate.split(" ")[0]   # 글의 날짜
    timePart = regDate.split(" ")[1]   # 글의 시각
    if datePart == today:
        return timePart
    else:
        return datePart


# ===== 메인 =====

print("== CLI 게시판 실행 ==")

last_article_id = 1
articles = [
    {"id": 1, "regDate": "2025-12-12 12:12:12", "updateDate": "2025-12-12 12:12:12", "title": "제목1", "body": "내용1"},
]

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
        break

    elif cmd == "article write":
        last_article_id += 1
        title = input("제목 : ")
        body = input("내용 : ")
        article = {
            "id": last_article_id,
            "regDate": now(),
            "updateDate": now(),
            "title": title,
            "body": body,
        }
        articles.append(article)
        print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
        if not articles:
            print("게시글이 없습니다")
        else:
            print("=========================================")
            print("   번호      /     제목       /     내용   /     작성일   ")
            for a in reversed(articles):
                print("   {}      /     {}       /     {}          /     {}   ".format(
                    a["id"], a["title"], a["body"], format_date(a["regDate"])))
            print("=========================================")

    elif cmd.startswith("article delete"):
        deletedId = parse_id(cmd)
        if deletedId is None:
            continue

        article = find_article(articles, deletedId)
        if article is None:
            print("{}번 글은 없습니다".format(deletedId))
            continue

        articles.remove(article)
        print("{}번 글이 삭제되었습니다".format(deletedId))

    elif cmd.startswith("article edit"):
        editedId = parse_id(cmd)
        if editedId is None:
            continue

        article = find_article(articles, editedId)
        if article is None:
            print("{}번 글은 없습니다".format(editedId))
            continue

        print("기존 제목 : {}".format(article["title"]))
        print("기존 내용 : {}".format(article["body"]))
        article["title"] = input("새 제목 : ")
        article["body"] = input("새 내용 : ")
        article["updateDate"] = now()
        print("{}번 글이 수정되었습니다".format(editedId))

    elif cmd.startswith("article detail"):
        detailId = parse_id(cmd)
        if detailId is None:
            continue

        article = find_article(articles, detailId)
        if article is None:
            print("{}번 글은 없습니다".format(detailId))
            continue

        print("번호 : {}".format(article["id"]))
        print("작성 날짜 : {}".format(article["regDate"]))
        print("수정 날짜 : {}".format(article["updateDate"]))
        print("제목 : {}".format(article["title"]))
        print("내용 : {}".format(article["body"]))

    else:
        print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

data = {'name': '홍길동', 'age': 25}

# %%
from datetime import datetime

print("== CLI 게시판 실행 ==")

last_article_id = 0
articles = [] # 게시글 저장소

class Img_Object:
    def __init__(self):
        self.x = 0
        self.y = 0



while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit": # 일단 기본 값이 뭐야 여기서. 형식은 또 뭐고 공통된 거 명령어 4개의 행동으로 이루어져 있지 않음?
      break

    elif cmd == "article write":
      last_article_id += 1
      id = last_article_id
      title = input("제목 : ")
      body = input("내용 : ")
      regDate = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
      updateDate = regDate
      article = {"id" : id, "regDate" : regDate, "updateDate": updateDate, "title" : title, "body" : body}
      articles.append(article)
      print("{}번 글이 생성되었습니다".format(last_article_id))

    elif cmd == "article list":
      if not articles:
        print("게시글이 없습니다")
      else:
        print("=========================================")
        print("   번호      /     제목       /     내용   /     날짜   ")
        for a in reversed(articles):
          print("   {}      /     {}       /     {}          /     {}   ".format(a["id"], a["title"], a["body"],a["regDate"]))
        print("=========================================")
    elif cmd.startswith("article delete"):
      cmdBits = cmd.split(" ")

      if len(cmdBits) < 3:
        print("명령어를 확인해주세요(길이 모자람)")
        continue

      if not cmdBits[2].isdigit():
        print("명령어를 확인해주세요(번호대신 str 입력)")
        continue

      deletedId = int(cmdBits[2])

      found = False # 못찾았다 를 가정

      for article in articles:
        if article["id"] == deletedId:
          articles.remove(article)
          print("{}번 글이 삭제되었습니다".format(cmdBits[2]))
          found = True # 진짜 찾았다!
          break
      if found == False: # 순회해서 다 뒤져봤는데 아직 found가 False라는 거는 True가 된 적이 없었다
      # else: # for ~ else 표현도 있음
        print("{}번 글은 없습니다".format(cmdBits[2]))
    elif cmd.startswith("article edit"):
      cmdBits = cmd.split(" ")

      if len(cmdBits) < 3:
        print("명령어를 확인해주세요(길이 모자람)")
        continue

      if not cmdBits[2].isdigit():
        print("명령어를 확인해주세요(번호대신 str 입력)")
        continue

      editedId = int(cmdBits[2])

      found = False

      for article in articles:
        if article["id"] == editedId:
          # 기존 제목 내용 보여주기
          print("기존 제목 : {}".format(article["title"]))
          print("기존 내용 : {}".format(article["body"]))
          # 새로 제목 내용 입력받아서 기존 내용 업데이트
          article["title"] = input("새 제목 : ")
          article["body"] = input("새 내용 : ")
          article["updateDate"] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
          print("{}번 글이 수정되었습니다".format(cmdBits[2]))
          found = True
          break
      if found == False:
        print("{}번 글은 없습니다".format(cmdBits[2]))
    elif cmd.startswith("article detail"):
      cmdBits = cmd.split(" ")

      if len(cmdBits) < 3:
        print("명령어를 확인해주세요(길이 모자람)")
        continue

      if not cmdBits[2].isdigit():
        print("명령어를 확인해주세요(번호대신 str 입력)")
        continue

      detailId = int(cmdBits[2])

      found = False

      for article in articles:
        if article["id"] == detailId:
          print("번호 : {}".format(article["id"]))
          print("작성 날짜 : {}".format(article["regDate"]))
          print("수정 날짜 : {}".format(article["updateDate"]))
          print("제목 : {}".format(article["title"]))
          print("내용 : {}".format(article["body"]))
          found = True
          break
      if found == False:
        print("{}번 글은 없습니다".format(cmdBits[2]))
    else:
      print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")

# %% [markdown]
# 여기까지가 혼자서 한거.

# %%
from datetime import datetime
from zoneinfo import ZoneInfo

now = datetime.now(ZoneInfo("Asia/Seoul"))
formatted_now = now.strftime('%Y년-%m월-%d일 %H시:%M분:%S초')

print("== CLI 게시판 실행 ==")

last_article_id = 0
articles = [] # 게시글 저장소

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
      break

    elif cmd == "article write":
      last_article_id += 1
      id = last_article_id
      title = input("제목 : ")
      body = input("내용 : ")
      article = {"id" : id, "title" : title, "body" : body}
      # print(article)
      articles.append(article)
      print("{}번 글이 생성되었습니다".format(last_article_id))


    elif cmd == "article list":
      if not articles:
        print("게시글이 없습니다.")
      else:
        print("=========================================")
        print("   번호      /     제목       /     내용   ")
        for a in reversed(articles):
          print("   {}      /     {}       /     {}   ".format(a["id"], a["title"], a["body"]))
        print("=========================================")


    elif cmd.startswith("article delete "):
      cmdBits = cmd.split(" ")
      if len(cmdBits) < 3:
        print('명령어를 확인해주세요(길이 모자람)')
        continue

      if not cmdBits[2].isdigit(): #isdigit()은 문자열 내의 모든 문자가 숫자로만 구성되어 있는지 확인하여주는건데, 3번째 인덱스에 있는
      #칸에 숫자만 입력이 되어있는지 확인하는 용도.
        print("명령어를 확인해주세요(숫자만)")
        continue

# 이 부분까지 왔다는거는 '명령어 입력을 잘 했다'의 상황
      target_id= int(cmdBits[2]) #이거를 이게 뭔데? 찾으려고 했던 id 번호 저장해야지 이제 왜 저장할거냐고? 그건 삭제할때 번호를 알면은 쓰이니까. 어따 쓸건데...일단 담아봐 담으면 이제 삭제를 해야지
      article_found_id = False # 타입이 다르다.
      for article in articles :  #타겟아이디 인트 값안 하니까
        if article ["id"]== target_id :# 밑에 아이디에서 1 =="1" 해버리니까 지나쳐버림 ;
          articles.remove(article) #리스트 입력된거 삭제 해서 아티클스 변수값에 담는다는 뜻.
          print("{}번 글이 삭제되었습니다.".format(target_id)) # 출력문만 삭제되었지 실제 리스트 값은 삭제 되지 않았음. 삭제해줘야함.
          article_found_id = True #만약 기사에서 글을 찾았으면 True로 파운드 아이디에 찾았다는 신호를 주고. 아니라면 for문을 지나쳐서 false가 되어버리면
          break # 삭제되면 다른거 삭제 안되게 또 멈추고.
      #삭제했으니 이제 뭐해야함? 삭제해서 내용이 없다면 내용이 없다고 출력을 해야겠지? 무슨 내용이 없어졌는데? 처음으로 입력한
      if article_found_id == False : # 아 이러면 id 만들어진 만큼 되네;;모두가 참이 되어버림 id , title body
        # 모두 있어야 하는데... 근데 remove 했는데 왜 또 만들어지는 걸까?
        print("{}번 게시물은 존재하지 않습니다.".format(target_id))#2번을 찾을 수가 없어~~~~~~~ 1번 을 삭제해버리면 2번이 안보여.리스트에... 왜냐
          #for 문 안에 갇혀있었거든. id 값이..?위로 올라가야지 그렇다고 if 문을 한단계 승격시키자니 while 문이 끝나버림;; 그럼 break를 안써야겠네.
          #for 문 빈 리스트가 되기 때문에 for문 안에서 안에 있는 코드들을 실행하지 않으면 false 나 true 둘 중에 하나의 반환으로 되는게 아니라 그냥 무시가 되는 것.
          # 따라서 없어진 리스트를 찾으려고 해서 무시하게 할 바엔 그냥 참 거짓을 담아(참이든 거짓이든 반대로 하면 됨)참이 되어 해당 글이 삭제 되었다는걸
          # 반대 상황을 가정해서 해야하고 true가 안되면 고정 값을 false로 해야지만 없을 시 false랑 매칭이 되기 대문에 위에다가 기사에서 찾은 id에 거짓의 고정 값을 달아준다.

    # 게시글 수정 (ex: article edit 1)
    elif cmd.startswith("article edit "): # article edit로 했을 때 true가 된다.~를 쳤을때 True 값으로 반환. article edit {} 치는 값으로 해야하기 때문에 공간을 확보해줘야한다.
        cmdBits = cmd.split(" ")  #스프릿으로 나눠준다.
        target_id = int(cmdBits[2]) #문자열 취급 되어있으니 정수 취급 해주고
        article_found_id = False #플래그 변수, 깃발을 올려! 그럼 출력! 혹은 멈춰! 찾기 위한 반복문을~

        if len(cmdBits) < 3:
          print('명령어를 확인해주세요(길이 모자람)')
          continue

        if not cmdBits[2].isdigit():
          print("명령어를 확인해주세요(숫자만)")
          continue


        for article in articles:
            if article["id"] == target_id:
                new_title = input("수정할 제목 : ")
                new_body = input("수정할 내용 : ")

                # 기존 딕셔너리의 값 변경
                article["title"] = new_title #새로운 타이틀에 담고서 변경
                article["body"] = new_body

                print("{}번 게시물이 수정되었습니다.".format(target_id))
                article_found_id= True
                break

        if not article_found_id:
            print("{}번 게시물은 존재하지 않습니다.".format(target_id))
        print(1)
    # 5. 게시글 상세보기 (ex: article detail 1) # 날짜 추가해야함
    elif cmd.startswith("article detail "):
        cmdBits = cmd.split(" ")
        target_id = int(cmdBits[2])
        article_found_id = False
        for article in articles:
            if article["id"] == target_id: # 숫자 값만 추출한 것. 원하는 아티클 디테일 번호만을 입력하면 그 내용만 인출하면 됨.
                print("=========================================")
                print("번호 : {}".format(article["id"]))
                print("제목 : {}".format(article["title"]))
                print("날짜 : {}".format(formatted_now))
                print("내용 : {}".format(article["body"]))
                print("=========================================")
                article_found_id = True
                break
# 음.. 시간대가 오늘 날이 되면 월 일 만 나오게 하고 어제면 연월일이 나오게 하면 되는 거아닌가?
#
        if not article_found_id:
            print("{}번 게시물은 존재하지 않습니다.".format(target_id))

    else:
      print("지원하지 않는 기능입니다")


print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 : 1
# 내용 : 2
# 1번 글이 생성되었습니다
# 명령어 ) article detail 1
# =========================================
# 번호 : 1
# 제목 : 1
# 날짜 : 2026년-07월-02일 14시:34분:07초
# 내용 : 2
# =========================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_458/2753198200.py in <cell line: 0>()
#      11
#      12 while True:
# ---> 13     cmd = input("명령어 ) ").strip()
#      14
#      15     if cmd == "exit":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from datetime import datetime
from zoneinfo import ZoneInfo

# 한국 시간대(Asia/Seoul) 지정하여 현재 시간 가져오기
now = datetime.now(ZoneInfo("Asia/Seoul"))

# 초를 제외하고 포매팅
formatted_now = now.strftime('%Y-%m-%d %H:%M:%S')

print(formatted_now)
# Out:
# 2026-07-02 13:05

# %% [markdown]
# 두 번째 해본
# cmd 입력값 조정 기능 추가하기. + 날씨 상세보기 기능 추가하기 // + 고정 저장 시간대 추가하고 기존 리스트에도 추가하기

# %%
print("== CLI 게시판 실행 ==")

last_article_id = 0
articles = []  # 게시글 저장소

while True:
    cmd = input("명령어 ) ").strip()

    if cmd == "exit":
        break

    # 1. 게시글 작성
    elif cmd == "article write":
        last_article_id += 1
        id = last_article_id
        title = input("제목 : ")
        body = input("내용 : ")
        article = {"id": id, "title": title, "body": body}
        articles.append(article)
        print("{}번 글이 생성되었습니다".format(last_article_id))

    # 2. 게시글 목록 조회
    elif cmd == "article list":
        if not articles:
            print("게시글이 없습니다")
        else:
            print("=========================================")
            print("번호    /    제목    /    내용")
            for a in reversed(articles):
                print("{:<6} /    {:<8} /    {}".format(a["id"], a["title"], a["body"]))
            print("=========================================")



    # 3. 게시글 삭제 (ex: article delete 1)
    elif cmd.startswith("article delete "):
        cmdBits = cmd.split(" ")

        # 입력된 ID 숫자를 가져옴.
        target_id = int(cmdBits[2])#쪼개지면 cmd "article delete 1" ->를 공백기준으로하면 ["article","delete", "1"]로 나눠짐. 이거를 다시 2번 자리의 비트값에 담았다면
        # 또다시 이 값을 저장해야겠지. 나중에 부르려면 그럼 타겟으로 삼고 아이디를. 음.. 이제 값을 찾을 수 있게 되었고 저장했으니 써야할 텐데. 어찌 쓰면 좋지?
        # 일단 자료가 있는지와 없는지 부터 구분해야겠다.  자료가 있는지 보려면 추가된 리스트 값에 아티클 아이디를 돌려보고, 없다면 게시물을 없다 얘기하고
        found = False

        for article in articles:
            if article["id"] == target_id:
                articles.remove(article)  # 아티클 리스트에서 추가된 아티클스(아이디에 해당하는) 해당 딕셔너리 삭제
                print("{}번 게시물이 삭제되었습니다.".format(target_id))
                found = True #트루 처리해서 멈추게 함. 삭제를 반복하는 걸. 만약 false라면 못찾았다고 해야하는데. 만일 파운드가 반대라면 존재하지 않는다라고
                break

        if not found:
            print("{}번 게시물은 존재하지 않습니다.".format(target_id)) # 맞다면 아래에 조건이 되어야 하기 때문에 처음 found 값을 not으로 한것임. 조건을 나중에 true로 하기 위해서

    # 4. 게시글 수정 (ex: article edit 1)
    elif cmd.startswith("article edit "): # article edit로 했을 때 true가 된다.~를 쳤을때 True 값으로 반환. article edit {} 치는 값으로 해야하기 때문에 공간을 확보해줘야한다.
        cmdBits = cmd.split(" ")  #스프릿으로 나눠준다.
        target_id = int(cmdBits[2]) #문자열 취급 되어있으니 정수 취급 해주고
        found = False #플래그 변수, 깃발을 올려! 그럼 출력! 혹은 멈춰! 찾기 위한 반복문을~

        for article in articles:
            if article["id"] == target_id:
                new_title = input("수정할 제목 : ")
                new_body = input("수정할 내용 : ")

                # 기존 딕셔너리의 값 변경
                article["title"] = new_title #새로운 타이틀에 담고서 변경
                article["body"] = new_body

                print("{}번 게시물이 수정되었습니다.".format(target_id))
                found = True
                break

        if not found:
            print("{}번 게시물은 존재하지 않습니다.".format(target_id))

    # 5. 게시글 상세보기 (ex: article detail 1) # 날짜 추가해야함
    elif cmd.startswith("article detail "):
        cmdBits = cmd.split(" ")
        target_id = int(cmdBits[2])
        found = False

        for article in articles:
            if article["id"] == target_id: # 숫자 값만 추출한 것. 원하는 아티클 디테일 번호만을 입력하면 그 내용만 인출하면 됨.
                print("=========================================")
                print("번호 : {}".format(article["id"]))
                print("제목 : {}".format(article["title"]))
                print("내용 : {}".format(article["body"]))
                print("=========================================")
                found = True
                break

        if not found:
            print("{}번 게시물은 존재하지 않습니다.".format(target_id))

    else:
        print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")

# %% [markdown]
# [{'id': 1, 'title': '1', 'content': '2'}, {'id': 2, 'title': '3', 'content': '4'}, {'id': 3, 'title': '5', 'content': '6'}]

# %% [markdown]
# 처음 수정 해본

# %%
print("== CLI 게시판 실행 ==")

# 게시글들을 저장할 리스트
articles = []
last_article_number = 0



while True: # 계속 하고 싶음. 명령어 계속 넣고 싶음.
    cmd = input("명령어 ) ").strip() # 공백 지우기 추가 양쪽

    if cmd == "exit":
        break

    elif cmd == "article write":
        last_article_number += 1
        title = input("제목 : ") # 담고
        content = input("내용 : ") # 담고

        # 게시글 정보를 딕셔너리로 만들어 리스트에 추가
        article = { # 다음단계 항상 순서를 기억하자... 순서대로 출력되는거니까. 인풋되고 나서 아티클에 담기는 거임. 내용들이. 조정하기 위한 부분이고 밑에 변수에 또 어펜드 해서 저장하는.control과 저장은 다르다.
            "id": last_article_number,
            "title": title,
            "content": content
        }
        articles.append(article) #articles.append(article)은 articles라는 이름의 리스트(목록) 맨 끝에 새로운 article 데이터를 추가하겠다. 아티클은 저장이 아닌 그냥 조립이고
        #이걸 저장을 하기 위해 아티클스 리스트를 추가해야만 한다. 1번째 하고나서 올라가면 1번째 자료들이 사라지니까.

        print("{}번 글이 생성 되었습니다.".format(last_article_number)) # 입력할때마다 숫자가 증가됨

    elif cmd == "article list":
        if not articles:
            print("등록된 게시글이 없습니다.")
            continue # 다시 하게끔 해야하니까. 넘어가게.

        print("========================================")
        print("번호    /    제목    /    내용")

        # 최신 글이 위로 오도록 리스트를 역순으로 순회
        for article in reversed(articles):  # 변수에 담고 아래 코드 실행! 즉, id 타이틀 콘탠트에 1번째 리스트 값을 넣어서 실행함.
            print("{} /    {} /    {}".format(article["id"], article["title"], article["content"])) # 딕셔너리 키 값을 넣어서 하면 벨류가 반환된다.
       #print(articles[0]), 이면 처음 추가되어 저장된 데이터가 호출된다.
       #print(articles[1]), 이면 두 번째 저장된 데이터가 출력된다.
      # reversed()가 원본을 유지한 채 새로운 역순 객체를 반환하는 것과 달리, .reverse()는 원본 리스트를 직접 수정(In-place)하며 반환값은 None입니다


        print("========================================")

    else:
        print("지원하지 않는 기능입니다.")

print("== CLI 게시판 종료 ==")

# %% [markdown]
# 만약 articles라는 리스트에 세 개의 글이 담겨 있다면 다음과 같이 작동합니다.첫 번째 바퀴: 첫 번째 글을 꺼내 article 변수에 담고, 아래 코드를 실행합니다.두 번째 바퀴: 두 번째 글을 꺼내 article 변수에 담고, 아래 코드를 실행합니다.세 번째 바퀴: 세 번째 글을 꺼내 article 변수에 담고, 아래 코드를 실행합니다.
#
#
#
# if not articles:는 "바구니가 비어 있다면(False라면)"이라는 조건문입니다.파이썬에서는 비어 있는 리스트 []를 False로 취급하기 때문에, not False가 되어 조건문 안의 코드가 실행됩니다.

# %%
# article = [1, "123", "abc"]
print(article[0])  # 이게 번호인가?
print(article[1])  # 이게 제목인가? 내용인가?

# 전체 게시글을 담는 리스트
articles = []

# 게시글 작성 예시
# 순서대로 0번=번호, 1번=제목, 2번=내용으로 약속하고 넣어야 합니다.
article1 = [1, "123", "abc"]
articles.append(article1)

article2 = [2, "456", "def"]
articles.append(article2)

# 출력할 때
for article in reversed(articles):
    # 인덱스 번호(0, 1, 2)로만 값을 가져와야 해서 코드가 직관적이지 않음
    print("번호: {}, 제목: {}, 내용: {}".format(article[0], article[1], article[2]))

# %%
# article = {"id": 1, "title": "123", "content": "abc"}
print(article["id"])       # 아, 번호구나!
print(article["title"])    # 아, 제목이구나!

# 전체 게시글을 담는 리스트
articles = []

# 게시글 작성 예시
# 순서 상관없이 Key(이름)를 지정해서 명확하게 넣습니다.
article1 = {
    "id": 1,
    "title": "123",
    "content": "abc"
}
articles.append(article1)

article2 = {
    "id": 2,
    "title": "456",
    "content": "def"
}
articles.append(article2)

# 출력할 때
for article in reversed(articles):
    # 인덱스 대신 "id", "title", "content"라는 이름으로 직접 꺼내 쓰므로 매우 직관적임
    print("번호: {}, 제목: {}, 내용: {}".format(article["id"], article["title"], article["content"]))
